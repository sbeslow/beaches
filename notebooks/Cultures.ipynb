# %%
import pandas as pd

# %%
beach_rows = pd.read_csv('data/Beach_Lab_Data.csv')
beach_rows = beach_rows.loc[~beach_rows['Beach'].isnull()]
beach_rows.head()
# Out:
#      Culture Test ID Culture Sample 1 Timestamp        Beach  \
# 376           103919     05/29/2007 12:00:00 AM  South Shore
# 377           110945     06/18/2014 12:00:00 AM       Howard
# 378            91005     07/15/2009 12:00:00 AM  12th Street
# 379            95216     08/21/2015 12:00:00 AM      Juneway
# 380            90110     06/21/2011 12:00:00 AM      Calumet
#
#      Culture Sample 1 Reading  Culture Sample 2 Reading  Culture Reading Mean  \
# 376                      16.0                       6.3                  10.0
# 377                       4.0                       4.0                   4.0
# 378                     167.0                     178.9                 172.8
# 379                       3.0                       1.0                   1.7
# 380                       3.0                       2.0                   2.4
#
#      Culture Note  Culture Sample Interval Culture Sample 2 Timestamp  \
# ...

# %%
culture_readings = beach_rows[['Beach', 'Culture Test ID', 'Culture Sample 1 Timestamp', 'Culture Sample 1 Reading', 'Culture Sample 2 Reading', 'Culture Reading Mean',
                               'Culture Note', 'Culture Sample Interval', 'Culture Sample 2 Timestamp']]
culture_readings.head()
# Out:
#            Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 376  South Shore           103919     05/29/2007 12:00:00 AM
# 377       Howard           110945     06/18/2014 12:00:00 AM
# 378  12th Street            91005     07/15/2009 12:00:00 AM
# 379      Juneway            95216     08/21/2015 12:00:00 AM
# 380      Calumet            90110     06/21/2011 12:00:00 AM
#
#      Culture Sample 1 Reading  Culture Sample 2 Reading  Culture Reading Mean  \
# 376                      16.0                       6.3                  10.0
# 377                       4.0                       4.0                   4.0
# 378                     167.0                     178.9                 172.8
# 379                       3.0                       1.0                   1.7
# 380                       3.0                       2.0                   2.4
#
#      Culture Note  Culture Sample Interval Culture Sample 2 Timestamp
# ...

# %%
culture_readings.dtypes
# Out:
# Beach                          object
# Culture Test ID                 int64
# Culture Sample 1 Timestamp     object
# Culture Sample 1 Reading      float64
# Culture Sample 2 Reading      float64
# Culture Reading Mean          float64
# Culture Note                  float64
# Culture Sample Interval       float64
# Culture Sample 2 Timestamp     object
# dtype: object

# %%
culture_readings['Culture Note'].unique()
# Out:
# array([ nan])

# %%
del culture_readings['Culture Note']
culture_readings.head()
# Out:
#            Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 376  South Shore           103919     05/29/2007 12:00:00 AM
# 377       Howard           110945     06/18/2014 12:00:00 AM
# 378  12th Street            91005     07/15/2009 12:00:00 AM
# 379      Juneway            95216     08/21/2015 12:00:00 AM
# 380      Calumet            90110     06/21/2011 12:00:00 AM
#
#      Culture Sample 1 Reading  Culture Sample 2 Reading  Culture Reading Mean  \
# 376                      16.0                       6.3                  10.0
# 377                       4.0                       4.0                   4.0
# 378                     167.0                     178.9                 172.8
# 379                       3.0                       1.0                   1.7
# 380                       3.0                       2.0                   2.4
#
#      Culture Sample Interval Culture Sample 2 Timestamp
# 376                      NaN                        NaN
# ...

# %%
culture_readings['Culture Sample 1 Timestamp'] = pd.to_datetime(culture_readings['Culture Sample 1 Timestamp'])
culture_readings['Culture Sample 2 Timestamp'] = pd.to_datetime(culture_readings['Culture Sample 2 Timestamp'])
culture_readings.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\opengov\beaches2017\notebooks\venv-beach-nb\lib\site-packages\pandas\tseries\tools.py in _convert_listlike(arg, box, format, name, tz)
#     409             try:
# --> 410                 values, tz = tslib.datetime_to_datetime64(arg)
#     411                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\tslib.pyx in pandas.tslib.datetime_to_datetime64 (pandas\tslib.c:33358)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-39-ba1a77d380ed> in <module>()
# ----> 1 culture_readings['Culture Sample 1 Timestamp'] = pd.to_datetime(culture_readings['Culture Sample 1 Timestamp'])
# ...

# %%
culture_readings.sort_values('Culture Sample 1 Timestamp', ascending=False)
# Out:
#                        Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 16993               Humboldt           114147     10/01/0016 10:00:00 AM
# 14309               Humboldt           114146     09/30/0016 10:05:00 AM
# 15783               Humboldt           114145     09/29/0016 10:00:00 AM
# 13601               Humboldt           114144     09/28/0016 10:00:00 AM
# 15953               Humboldt           114143     09/25/0016 10:00:00 AM
# 13432               Humboldt           114142     09/24/0016 10:00:00 AM
# 17204               Humboldt           114140     09/22/0016 10:00:00 AM
# 13885               Humboldt           114139     09/21/0016 10:00:00 AM
# 13979               Humboldt           114141     09/20/2016 10:00:00 AM
# 1067                 Rainbow            94373     09/18/2015 12:00:00 AM
# 681              63rd Street            94375     09/18/2015 12:00:00 AM
# 11005             Oak Street            94381     09/18/2015 12:00:00 AM
# ...

# %%
def update_bogus_timestamp(timestamp):
    if str(timestamp).lower() == 'nan':
        return None
    the_date = timestamp.split(' ')[0]
    year = the_date.split('/')[2]
    if year == '0016':
        updated_timestamp = '/'.join([timestamp.split('/')[0], timestamp.split('/')[1], '2016']) + ' ' + timestamp.split(' ')[1]
        timestamp = updated_timestamp
    return pd.to_datetime(timestamp)
update_bogus_timestamp('09/25/0016 10:00:00 AM')
# Out:
# Timestamp('2016-09-25 10:00:00')

# %%
culture_readings['sample_1_timestamp'] = culture_readings['Culture Sample 1 Timestamp'].apply(update_bogus_timestamp)
culture_readings['sample_2_timestamp'] = culture_readings['Culture Sample 2 Timestamp'].apply(update_bogus_timestamp)
culture_readings.head()
# Out:
# d:\opengov\beaches2017\notebooks\venv-beach-nb\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# d:\opengov\beaches2017\notebooks\venv-beach-nb\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 376  South Shore           103919     05/29/2007 12:00:00 AM
# 377       Howard           110945     06/18/2014 12:00:00 AM
# ...

# %%
culture_readings
# Out:
#                        Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 376              South Shore           103919     05/29/2007 12:00:00 AM
# 377                   Howard           110945     06/18/2014 12:00:00 AM
# 378              12th Street            91005     07/15/2009 12:00:00 AM
# 379                  Juneway            95216     08/21/2015 12:00:00 AM
# 380                  Calumet            90110     06/21/2011 12:00:00 AM
# 381                   Foster            98174     06/07/2007 12:00:00 AM
# 382                 Montrose           113691     08/05/2016 08:35:00 AM
# 383                   Foster           110739     08/09/2012 12:00:00 AM
# 384                  Juneway           101039     08/20/2007 12:00:00 AM
# 385              63rd Street            88385     07/22/2010 12:00:00 AM
# 386              12th Street            87602     06/21/2010 12:00:00 AM
# 387                   Foster            99572     08/31/2007 12:00:00 AM
# ...

# %%
culture_readings['sample'] = culture_readings['Culture Sample 1 Reading']
culture_readings.head()
# Out:
# d:\opengov\beaches2017\notebooks\venv-beach-nb\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 376  South Shore           103919     05/29/2007 12:00:00 AM
# 377       Howard           110945     06/18/2014 12:00:00 AM
# 378  12th Street            91005     07/15/2009 12:00:00 AM
# 379      Juneway            95216     08/21/2015 12:00:00 AM
# 380      Calumet            90110     06/21/2011 12:00:00 AM
#
#      Culture Sample 1 Reading  Culture Sample 2 Reading  Culture Reading Mean  \
# 376                      16.0                       6.3                  10.0
# ...

# %%
culture_readings.loc[culture_readings['sample'].isnull()]
# Out:
#                        Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 431                  Calumet           102724     05/26/2006 12:00:00 AM
# 653              12th Street            97884     07/05/2006 12:00:00 AM
# 683                   Howard           111419     06/07/2012 12:00:00 AM
# 885                    Leone           104106     06/09/2006 12:00:00 AM
# 951               Oak Street            97552     06/12/2011 12:00:00 AM
# 1153             12th Street            97550     06/12/2011 12:00:00 AM
# 1210                Montrose           104099     06/09/2006 12:00:00 AM
# 1273                  Rogers            97899     07/05/2006 12:00:00 AM
# 1554                  Rogers           108736     07/16/2012 12:00:00 AM
# 1637                Osterman           106425     06/19/2012 12:00:00 AM
# 1702             57th Street           110440     07/08/2014 12:00:00 AM
# 1811                 Calumet            97543     06/12/2011 12:00:00 AM
# ...

# %%
culture_readings.loc[culture_readings['sample'].isnull(), 'sample'] = culture_readings.loc[culture_readings['sample'].isnull(), 'Culture Sample 2 Reading']
# Out:
# d:\opengov\beaches2017\notebooks\venv-beach-nb\lib\site-packages\pandas\core\indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
culture_readings.loc[culture_readings['sample'].isnull()]
# Out:
#                        Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 431                  Calumet           102724     05/26/2006 12:00:00 AM
# 683                   Howard           111419     06/07/2012 12:00:00 AM
# 885                    Leone           104106     06/09/2006 12:00:00 AM
# 951               Oak Street            97552     06/12/2011 12:00:00 AM
# 1153             12th Street            97550     06/12/2011 12:00:00 AM
# 1210                Montrose           104099     06/09/2006 12:00:00 AM
# 1811                 Calumet            97543     06/12/2011 12:00:00 AM
# 2190                  Howard            97762     07/12/2006 12:00:00 AM
# 2503             Ohio Street           104096     06/09/2006 12:00:00 AM
# 3066                Osterman            97558     06/12/2011 12:00:00 AM
# 3261                  Rogers           104110     06/09/2006 12:00:00 AM
# 3473             63rd Street            97546     06/12/2011 12:00:00 AM
# ...

# %%
culture_readings = culture_readings.loc[~culture_readings['sample'].isnull()]
culture_readings.head()
# Out:
#            Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 376  South Shore           103919     05/29/2007 12:00:00 AM
# 377       Howard           110945     06/18/2014 12:00:00 AM
# 378  12th Street            91005     07/15/2009 12:00:00 AM
# 379      Juneway            95216     08/21/2015 12:00:00 AM
# 380      Calumet            90110     06/21/2011 12:00:00 AM
#
#      Culture Sample 1 Reading  Culture Sample 2 Reading  Culture Reading Mean  \
# 376                      16.0                       6.3                  10.0
# 377                       4.0                       4.0                   4.0
# 378                     167.0                     178.9                 172.8
# 379                       3.0                       1.0                   1.7
# 380                       3.0                       2.0                   2.4
#
#      Culture Sample Interval Culture Sample 2 Timestamp sample_1_timestamp  \
# ...

# %%
culture_readings
# Out:
#                        Beach  Culture Test ID Culture Sample 1 Timestamp  \
# 376              South Shore           103919     05/29/2007 12:00:00 AM
# 377                   Howard           110945     06/18/2014 12:00:00 AM
# 378              12th Street            91005     07/15/2009 12:00:00 AM
# 379                  Juneway            95216     08/21/2015 12:00:00 AM
# 380                  Calumet            90110     06/21/2011 12:00:00 AM
# 381                   Foster            98174     06/07/2007 12:00:00 AM
# 382                 Montrose           113691     08/05/2016 08:35:00 AM
# 383                   Foster           110739     08/09/2012 12:00:00 AM
# 384                  Juneway           101039     08/20/2007 12:00:00 AM
# 385              63rd Street            88385     07/22/2010 12:00:00 AM
# 386              12th Street            87602     06/21/2010 12:00:00 AM
# 387                   Foster            99572     08/31/2007 12:00:00 AM
# ...
